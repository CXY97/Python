# %% [markdown]
# # Pyecharts 学习总结

# %% [markdown]
# ## 一、 入门

# %% [markdown]
# ### 1.1 [各种图](http://gallery.pyecharts.org/#/README)
#
# 点击案例下面的 `Demo-gallery` 便可以进去看到官网的案例

# %%
# Bar图
from pyecharts.charts import Bar

bar = (
    Bar()
    .add_xaxis(['20-24', '25-28', '28-30'])  # 单纯的x轴坐标， 叠加只会显示最后一个x轴 
    .add_yaxis("K1数量分布", [2, 7, 2])      # y轴数据
    .add_yaxis("K2数量分布", [1, 4, 6])      # y轴可以叠加
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0eae959c00e64ec0b3be87fe2f32c729" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0eae959c00e64ec0b3be87fe2f32c729 = echarts.init(
#                     document.getElementById('0eae959c00e64ec0b3be87fe2f32c729'), 'white', {renderer: 'canvas'});
#                 var option_0eae959c00e64ec0b3be87fe2f32c729 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "K1\u6570\u91cf\u5206\u5e03",
#             "data": [
#                 2,
#                 7,
#                 2
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "K2\u6570\u91cf\u5206\u5e03",
#             "data": [
#                 1,
#                 4,
#                 6
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "K1\u6570\u91cf\u5206\u5e03",
#                 "K2\u6570\u91cf\u5206\u5e03"
#             ],
#             "selected": {
#                 "K1\u6570\u91cf\u5206\u5e03": true,
#                 "K2\u6570\u91cf\u5206\u5e03": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "20-24",
#                 "25-28",
#                 "28-30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_0eae959c00e64ec0b3be87fe2f32c729.setOption(option_0eae959c00e64ec0b3be87fe2f32c729);
#         });
#     </script>

# %%
from pyecharts.faker import Faker
import pyecharts.options as opts

bar = (
    Bar()
    .add_xaxis(Faker.choose())
    # 数据堆叠，同个类目轴上系列配置相同的　stack　值可以堆叠放置
    # stack: Optional[str] = None
    .add_yaxis("A", Faker.values(), stack="stack1")
    .add_yaxis("B", Faker.values(), stack="stack1")
    .add_yaxis("C", Faker.values())  # 可以尝试加上 , stack="stack1" 看效果
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))  # 关闭数据值显示
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据"))  # shift + tab查看参数
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9b2fe721a6624810b8eec41de1876e74" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9b2fe721a6624810b8eec41de1876e74 = echarts.init(
#                     document.getElementById('9b2fe721a6624810b8eec41de1876e74'), 'white', {renderer: 'canvas'});
#                 var option_9b2fe721a6624810b8eec41de1876e74 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "data": [
#                 74,
#                 110,
#                 67,
#                 21,
#                 94,
#                 71,
#                 150
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "data": [
#                 134,
#                 136,
#                 100,
#                 108,
#                 137,
#                 102,
#                 142
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "C",
#             "data": [
#                 61,
#                 81,
#                 140,
#                 36,
#                 101,
#                 110,
#                 68
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true,
#                 "C": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u5806\u53e0\u6570\u636e",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9b2fe721a6624810b8eec41de1876e74.setOption(option_9b2fe721a6624810b8eec41de1876e74);
#         });
#     </script>

# %%
c = (
    Bar(init_opts=opts.InitOpts(page_title="bar页面"))
    .add_xaxis(Faker.days_attrs)
    .add_yaxis("商家A", Faker.days_values)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
        datazoom_opts=[opts.DataZoomOpts(type_="slider")]
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e98b3f8f5c88464d93cebf7596491c40" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e98b3f8f5c88464d93cebf7596491c40 = echarts.init(
#                     document.getElementById('e98b3f8f5c88464d93cebf7596491c40'), 'white', {renderer: 'canvas'});
#                 var option_e98b3f8f5c88464d93cebf7596491c40 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 7,
#                 13,
#                 20,
#                 13,
#                 9,
#                 27,
#                 1,
#                 25,
#                 15,
#                 14,
#                 14,
#                 29,
#                 8,
#                 22,
#                 27,
#                 12,
#                 16,
#                 22,
#                 30,
#                 9,
#                 18,
#                 9,
#                 25,
#                 5,
#                 30,
#                 3,
#                 24,
#                 21,
#                 16,
#                 5
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u6c34\u5e73\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false
#         }
#     ]
# };
#                 chart_e98b3f8f5c88464d93cebf7596491c40.setOption(option_e98b3f8f5c88464d93cebf7596491c40);
#         });
#     </script>

# %%
import json
from pyecharts.charts import Page, Pie

f = open(r"C:\Users\XY\Desktop\更新\NotebookPro\pyecharts数据集\pies.json")
data = json.load(f)
name = data['name']
sales = data['sales']
sales_volume = data['sales_volume']

data
# Out:
# {'name': ['彩漂', '吸色片', '衣领净', '漂白剂', '干洗剂', '衣物柔顺剂', '洗衣粉', '洗衣皂', '洗衣液'],
#  'sales': [2525, 6445, 4541, 5097, 21739, 25050, 38075, 14680, 331977],
#  'sales_volume': [358054,
#   521500,
#   541209,
#   1047869,
#   2091239,
#   2650622,
#   4721336,
#   5468538,
#   24387805]}

# %%
pie = (
    Pie()
    .add("销售额", [list(i) for i in zip(name,sales)], radius=["20%", "60%"])  # radius不可写0.2, 且带上引号
    .set_global_opts(
            title_opts=opts.TitleOpts(title="衣服清洗剂市场占比",subtitle="销售额"),
            legend_opts=opts.LegendOpts(
                orient = "horizontal", pos_top = "5%", pos_left = "10%"
            )
    )
    .set_series_opts(
            label_opts=opts.LabelOpts(
                formatter="{b}: {c}"  # a: 销售额 b：类别 c：数量
            )
    )
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2dca0c341d184623ad6e215e3d71c250" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2dca0c341d184623ad6e215e3d71c250 = echarts.init(
#                     document.getElementById('2dca0c341d184623ad6e215e3d71c250'), 'white', {renderer: 'canvas'});
#                 var option_2dca0c341d184623ad6e215e3d71c250 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u9500\u552e\u989d",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5f69\u6f02",
#                     "value": 2525
#                 },
#                 {
#                     "name": "\u5438\u8272\u7247",
#                     "value": 6445
#                 },
#                 {
#                     "name": "\u8863\u9886\u51c0",
#                     "value": 4541
#                 },
#                 {
#                     "name": "\u6f02\u767d\u5242",
#                     "value": 5097
#                 },
#                 {
#                     "name": "\u5e72\u6d17\u5242",
#                     "value": 21739
#                 },
#                 {
#                     "name": "\u8863\u7269\u67d4\u987a\u5242",
#                     "value": 25050
#                 },
#                 {
#                     "name": "\u6d17\u8863\u7c89",
#                     "value": 38075
#                 },
#                 {
#                     "name": "\u6d17\u8863\u7682",
#                     "value": 14680
#                 },
#                 {
#                     "name": "\u6d17\u8863\u6db2",
#                     "value": 331977
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "60%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5f69\u6f02",
#                 "\u5438\u8272\u7247",
#                 "\u8863\u9886\u51c0",
#                 "\u6f02\u767d\u5242",
#                 "\u5e72\u6d17\u5242",
#                 "\u8863\u7269\u67d4\u987a\u5242",
#                 "\u6d17\u8863\u7c89",
#                 "\u6d17\u8863\u7682",
#                 "\u6d17\u8863\u6db2"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "10%",
#             "top": "5%",
#             "orient": "horizontal",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8863\u670d\u6e05\u6d17\u5242\u5e02\u573a\u5360\u6bd4",
#             "subtext": "\u9500\u552e\u989d",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2dca0c341d184623ad6e215e3d71c250.setOption(option_2dca0c341d184623ad6e215e3d71c250);
#         });
#     </script>

# %%
import datetime, random

# Calendar
from pyecharts.charts import Calendar

begin = datetime.date(2020, 1, 1)
end = datetime.date.today()
data = [
    [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
    for i in range((end - begin).days + 1)
]

cal = (
    Calendar()
    .add("xxx", data, calendar_opts=opts.CalendarOpts(range_="2020"))  # shift+tab
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Calendar-2020年微信步数情况"),
        visualmap_opts=opts.VisualMapOpts(
            max_=20000,
            min_=500,
            orient="horizontal",  # 水平方向
            is_piecewise=True,    # 设置分段
            pos_top="220px",      # 上边距
            pos_left="80px",      # 左边距
        )
    )
)

cal.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3a7345df55fa434480b475c82394d1e6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3a7345df55fa434480b475c82394d1e6 = echarts.init(
#                     document.getElementById('3a7345df55fa434480b475c82394d1e6'), 'white', {renderer: 'canvas'});
#                 var option_3a7345df55fa434480b475c82394d1e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "xxx",
#             "data": [
#                 [
#                     "2020-01-01",
#                     5950
#                 ],
#                 [
#                     "2020-01-02",
#                     3564
#                 ],
#                 [
#                     "2020-01-03",
#                     23224
#                 ],
#                 [
#                     "2020-01-04",
#                     1405
#                 ],
#                 [
#                     "2020-01-05",
#                     17992
#                 ],
#                 [
#                     "2020-01-06",
#                     5414
#                 ],
#                 [
#                     "2020-01-07",
#                     13116
#                 ],
#                 [
#                     "2020-01-08",
#                     17704
#                 ],
#                 [
#                     "2020-01-09",
#                     17081
#                 ],
#                 [
#                     "2020-01-10",
#                     7713
#                 ],
#                 [
#                     "2020-01-11",
#                     21423
#                 ],
#                 [
#                     "2020-01-12",
#                     15815
#                 ],
#                 [
#                     "2020-01-13",
#                     9343
#                 ],
#                 [
#                     "2020-01-14",
#                     7095
#                 ],
#                 [
#                     "2020-01-15",
#                     13546
#                 ],
#                 [
#                     "2020-01-16",
#                     9278
#                 ],
#                 [
#                     "2020-01-17",
#                     10278
#                 ],
#                 [
#                     "2020-01-18",
#                     15707
#                 ],
#                 [
#                     "2020-01-19",
#                     10360
#                 ],
#                 [
#                     "2020-01-20",
#                     21880
#                 ],
#                 [
#                     "2020-01-21",
#                     2612
#                 ],
#                 [
#                     "2020-01-22",
#                     10424
#                 ],
#                 [
#                     "2020-01-23",
#                     20911
#                 ],
#                 [
#                     "2020-01-24",
#                     8383
#                 ],
#                 [
#                     "2020-01-25",
#                     17232
#                 ],
#                 [
#                     "2020-01-26",
#                     10742
#                 ],
#                 [
#                     "2020-01-27",
#                     2203
#                 ],
#                 [
#                     "2020-01-28",
#                     9149
#                 ],
#                 [
#                     "2020-01-29",
#                     1131
#                 ],
#                 [
#                     "2020-01-30",
#                     1258
#                 ],
#                 [
#                     "2020-01-31",
#                     16984
#                 ],
#                 [
#                     "2020-02-01",
#                     3887
#                 ],
#                 [
#                     "2020-02-02",
#                     9560
#                 ],
#                 [
#                     "2020-02-03",
#                     9571
#                 ],
#                 [
#                     "2020-02-04",
#                     18820
#                 ],
#                 [
#                     "2020-02-05",
#                     12993
#                 ],
#                 [
#                     "2020-02-06",
#                     23367
#                 ],
#                 [
#                     "2020-02-07",
#                     11511
#                 ],
#                 [
#                     "2020-02-08",
#                     11289
#                 ],
#                 [
#                     "2020-02-09",
#                     18455
#                 ],
#                 [
#                     "2020-02-10",
#                     20713
#                 ],
#                 [
#                     "2020-02-11",
#                     16142
#                 ],
#                 [
#                     "2020-02-12",
#                     13289
#                 ],
#                 [
#                     "2020-02-13",
#                     18378
#                 ],
#                 [
#                     "2020-02-14",
#                     16658
#                 ],
#                 [
#                     "2020-02-15",
#                     6222
#                 ],
#                 [
#                     "2020-02-16",
#                     22808
#                 ],
#                 [
#                     "2020-02-17",
#                     6293
#                 ],
#                 [
#                     "2020-02-18",
#                     7274
#                 ],
#                 [
#                     "2020-02-19",
#                     18422
#                 ],
#                 [
#                     "2020-02-20",
#                     9337
#                 ],
#                 [
#                     "2020-02-21",
#                     18713
#                 ],
#                 [
#                     "2020-02-22",
#                     22905
#                 ],
#                 [
#                     "2020-02-23",
#                     14547
#                 ],
#                 [
#                     "2020-02-24",
#                     3741
#                 ],
#                 [
#                     "2020-02-25",
#                     5557
#                 ],
#                 [
#                     "2020-02-26",
#                     23610
#                 ],
#                 [
#                     "2020-02-27",
#                     24932
#                 ],
#                 [
#                     "2020-02-28",
#                     3230
#                 ],
#                 [
#                     "2020-02-29",
#                     14059
#                 ],
#                 [
#                     "2020-03-01",
#                     23090
#                 ],
#                 [
#                     "2020-03-02",
#                     14271
#                 ],
#                 [
#                     "2020-03-03",
#                     10335
#                 ],
#                 [
#                     "2020-03-04",
#                     8285
#                 ],
#                 [
#                     "2020-03-05",
#                     9585
#                 ],
#                 [
#                     "2020-03-06",
#                     6341
#                 ],
#                 [
#                     "2020-03-07",
#                     13087
#                 ],
#                 [
#                     "2020-03-08",
#                     6723
#                 ]

# %%
from pyecharts.charts import HeatMap
from pyecharts import options as opts
from pyecharts.faker import Faker
import random

data = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]

heat = (HeatMap()
        .add_xaxis(Faker.clock)
        .add_yaxis("访客数", 
                   Faker.week, 
                   data,
                   label_opts=opts.LabelOpts(is_show=True, position="inside"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="HeatMap-基本示例", subtitle="我是副标题"),
            visualmap_opts=opts.VisualMapOpts(),
            legend_opts=opts.LegendOpts(is_show=False))
       )

heat.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c7af516c652c4af89412ff6fb3ae7691" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c7af516c652c4af89412ff6fb3ae7691 = echarts.init(
#                     document.getElementById('c7af516c652c4af89412ff6fb3ae7691'), 'white', {renderer: 'canvas'});
#                 var option_c7af516c652c4af89412ff6fb3ae7691 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u8bbf\u5ba2\u6570",
#             "data": [
#                 [
#                     0,
#                     0,
#                     17
#                 ],
#                 [
#                     0,
#                     1,
#                     50
#                 ],
#                 [
#                     0,
#                     2,
#                     34
#                 ],
#                 [
#                     0,
#                     3,
#                     48
#                 ],
#                 [
#                     0,
#                     4,
#                     4
#                 ],
#                 [
#                     0,
#                     5,
#                     18
#                 ],
#                 [
#                     0,
#                     6,
#                     9
#                 ],
#                 [
#                     1,
#                     0,
#                     9
#                 ],
#                 [
#                     1,
#                     1,
#                     19
#                 ],
#                 [
#                     1,
#                     2,
#                     50
#                 ],
#                 [
#                     1,
#                     3,
#                     26
#                 ],
#                 [
#                     1,
#                     4,
#                     27
#                 ],
#                 [
#                     1,
#                     5,
#                     45
#                 ],
#                 [
#                     1,
#                     6,
#                     7
#                 ],
#                 [
#                     2,
#                     0,
#                     2
#                 ],
#                 [
#                     2,
#                     1,
#                     3
#                 ],
#                 [
#                     2,
#                     2,
#                     8
#                 ],
#                 [
#                     2,
#                     3,
#                     49
#                 ],
#                 [
#                     2,
#                     4,
#                     34
#                 ],
#                 [
#                     2,
#                     5,
#                     20
#                 ],
#                 [
#                     2,
#                     6,
#                     7
#                 ],
#                 [
#                     3,
#                     0,
#                     4
#                 ],
#                 [
#                     3,
#                     1,
#                     12
#                 ],
#                 [
#                     3,
#                     2,
#                     15
#                 ],
#                 [
#                     3,
#                     3,
#                     12
#                 ],
#                 [
#                     3,
#                     4,
#                     46
#                 ],
#                 [
#                     3,
#                     5,
#                     37
#                 ],
#                 [
#                     3,
#                     6,
#                     18
#                 ],
#                 [
#                     4,
#                     0,
#                     27
#                 ],
#                 [
#                     4,
#                     1,
#                     25
#                 ],
#                 [
#                     4,
#                     2,
#                     12
#                 ],
#                 [
#                     4,
#                     3,
#                     33
#                 ],
#                 [
#                     4,
#                     4,
#                     8
#                 ],
#                 [
#                     4,
#                     5,
#                     9
#                 ],
#                 [
#                     4,
#                     6,
#                     25
#                 ],
#                 [
#                     5,
#                     0,
#                     1
#                 ],
#                 [
#                     5,
#                     1,
#                     50
#                 ],
#                 [
#                     5,
#                     2,
#                     15
#                 ],
#                 [
#                     5,
#                     3,
#                     28
#                 ],
#                 [
#                     5,
#                     4,
#                     44
#                 ],
#                 [
#                     5,
#                     5,
#                     31
#                 ],
#                 [
#                     5,
#                     6,
#                     38
#                 ],
#                 [
#                     6,
#                     0,
#                     12
#                 ],
#                 [
#                     6,
#                     1,
#                     29
#                 ],
#                 [
#                     6,
#                     2,
#                     0
#                 ],
#                 [
#                     6,
#                     3,
#                     31
#                 ],
#                 [
#                     6,
#                     4,
#                     0
#                 ],
#                 [
#                     6,
#                     5,
#                     41
#                 ],
#                 [
#                     6,
#                     6,
#                     16
#                 ],
#                 [
#                     7,
#                     0,
#                     36
#                 ],
#                 [
#                     7,
#                     1,
#                     11
#                 ],
#                 [
#                     7,
#                     2,
#                     45
#                 ],
#                 [
#                     7,
#                     3,
#                     16
#                 ],
#                 [
#                     7,
#                     4,
#                     24
#                 ],
#                 [
#                     7,
#                     5,
#                     25
#                 ],
#                 [
#                     7,
#                     6,
#                     42
#                 ],
#                 [
#                     8,
#                     0,
#                     50
#                 ],
#                 [
#                     8,
#                     1,
#                     19
#                 ],
#                 [
#                     8,
#                     2,
#                     32
#                 ],
#                 [
#                     8,
#                     3,
#                     35
#                 ],
#                 [
#                     8,
#                     4,
#                     25
#                 ],
#                 [
#                     8,
#                     5,
#                     35
#                 ],
#                 [

# %%
# 词云
from pyecharts.charts import WordCloud

words = [
    ("火箭", 10000), ("勇士库里", 8888), ("哈登", 6386),
    ("金州拉文", 5055), ("杜兰特", 6467), ("戳眼", 2244), ("NBA", 1868),
    ("季后赛", 1484), ("约老师", 1112), ("利拉德", 865),
    ("双卡双待", 847), ("字母歌MVP", 5582), ("卡哇伊", 555),
    ("猛龙", 550), ("大帝", 462), ("西蒙斯不投三分", 366),("JB", 360), ("科尔垃圾", 282),
    ("格林公式", 273), ("欧文", 2650),
]


def wordcloud_base() -> WordCloud:
    c = (
        WordCloud()
        .add("", words, word_size_range=[20, 50], shape="star", word_gap=10)  # 前三个参数必传！ mask_image="path/image.jpg" 自定义
        .set_global_opts(title_opts=opts.TitleOpts(title="WordCloud初探"))
    )
    return c

wordcloud_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="f66cd950e310451f8d10c9a2a8be6915" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_f66cd950e310451f8d10c9a2a8be6915 = echarts.init(
#                     document.getElementById('f66cd950e310451f8d10c9a2a8be6915'), 'white', {renderer: 'canvas'});
#                 var option_f66cd950e310451f8d10c9a2a8be6915 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 10,
#             "sizeRange": [
#                 20,
#                 50
#             ],
#             "data": [
#                 {
#                     "name": "\u706b\u7bad",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,32,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52c7\u58eb\u5e93\u91cc",
#                     "value": 8888,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(138,79,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u767b",
#                     "value": 6386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,91,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91d1\u5dde\u62c9\u6587",
#                     "value": 5055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,136,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u675c\u5170\u7279",
#                     "value": 6467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,100,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6233\u773c",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,137,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NBA",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,151,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b63\u540e\u8d5b",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,121,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ea6\u8001\u5e08",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,30,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5229\u62c9\u5fb7",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,59,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u5361\u53cc\u5f85",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,64,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b57\u6bcd\u6b4cMVP",
#                     "value": 5582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,63,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5361\u54c7\u4f0a",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,81,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u731b\u9f99",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,41,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u5e1d",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,149,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u897f\u8499\u65af\u4e0d\u6295\u4e09\u5206",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,92,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "JB",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(138,66,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u79d1\u5c14\u5783\u573e",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,64,126)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u683c\u6797\u516c\u5f0f",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,61,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b27\u6587",
#                     "value": 2650,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,103,73)"
#                         }
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "sh

# %%
import json

from pyecharts import options as opts
from pyecharts.charts import Page, Line  # 多图展示Page


f = open(r"C:\Users\XY\Desktop\更新\NotebookPro\pyecharts数据集\pies.json")
data = json.load(f)
name = data['name']
sales = data['sales']
sales_volume = data['sales_volume']
 
bar = (
        Bar()
        .add_xaxis(name)
        .add_yaxis("成交量", [sv for sv in sales_volume])
        .add_yaxis("销售额", [s  for s in sales]) 
        .set_global_opts(
            title_opts=opts.TitleOpts(title="衣服清洗剂市场占比柱形图"),
        )
        .reversal_axis()  # 添加此句, 柱状图变条形图
        .set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max",name="最大值"),opts.MarkPointItem(type_="min",name="最小值"),])
        )
         
)
# bar.render_notebook()


f = open(r"C:\Users\XY\Desktop\更新\NotebookPro\pyecharts数据集\lines.json")
data = json.load(f)

date = data['date']
sales1 = data['sales1']
sales2 = data['sales2']

line = (
        Line()
        .add_xaxis(date)
        .add_yaxis("成交量",sales1,
            markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average",name="平均值")]),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max",name="最大值"),opts.MarkPointItem(type_="min",name="最小值")],symbol="diamond",symbol_size=30),  
        )
        .add_yaxis(
            "销售额",sales2,
            markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average",name="平均值")]),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max",name="最大值"),
                                                    opts.MarkPointItem(type_="min",name="最小值")],
                                             )  
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="洗衣液月销售情况"),
            xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
            yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
        )
    )
# line.render_notebook()

page = Page(layout=Page.SimplePageLayout)
page.add(
    bar, 
    line
)

page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2f1090a5dbfd452280099819a5f6820b" style="width:900px; height:500px;"></div>
#         <div id="9c3b4caab85a400280aa475d508be270" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2f1090a5dbfd452280099819a5f6820b = echarts.init(
#                     document.getElementById('2f1090a5dbfd452280099819a5f6820b'), 'white', {renderer: 'canvas'});
#                 var option_2f1090a5dbfd452280099819a5f6820b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6210\u4ea4\u91cf",
#             "data": [
#                 358054,
#                 521500,
#                 541209,
#                 1047869,
#                 2091239,
#                 2650622,
#                 4721336,
#                 5468538,
#                 24387805
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u989d",
#             "data": [
#                 2525,
#                 6445,
#                 4541,
#                 5097,
#                 21739,
#                 25050,
#                 38075,
#                 14680,
#                 331977
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6210\u4ea4\u91cf",
#                 "\u9500\u552e\u989d"
#             ],
#             "selected": {
#                 "\u6210\u4ea4\u91cf": true,
#                 "\u9500\u552e\u989d": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5f69\u6f02",
#                 "\u5438\u8272\u7247",
#                 "\u8863\u9886\u51c0",
#                 "\u6f02\u767d\u5242",
#                 "\u5e72\u6d17\u5242",
#                 "\u8863\u7269\u67d4\u987a\u5242",
#                 "\u6d17\u8863\u7c89",
#                 "\u6d17\u8863\u7682",
#                 "\u6d17\u8863\u6db2"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u8863\u670d\u6e05\u6d17\u5242\u5e02\u573a\u5360\u6bd4\u67f1\u5f62\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2f1090a5dbfd452280099819a5f6820b.setOption(option_2f1090a5dbfd452280099819a5f6820b);
#                 var chart_9c3b4caab85a400280aa475d508be270 = echarts.init(
#                     document.getElementById('9c3b4caab85a400280aa475d508be270'), 'white', {renderer: 'canvas'});
#                 var option_9c3b4caab85a400280aa475d508be270 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6210\u4ea4\u91cf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1\u6708",
#                     128
#                 ],
#                 [
#                     "2\u6708",
#                     100
#                 ],
#                 [
#                     "3\u6708",
#                     188
#                 ],
#                 [
#                     "4\u6708",

# %%
from pyecharts.charts import Liquid
import pyecharts.options as opts

liquid = (
    Liquid()
    .add("完成率", [ 0.56])
    .set_global_opts(title_opts=opts.TitleOpts(title="指标完成情况"))
)
 
liquid .render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="c3041e0f569e4cc6b7e877fef6358fbd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_c3041e0f569e4cc6b7e877fef6358fbd = echarts.init(
#                     document.getElementById('c3041e0f569e4cc6b7e877fef6358fbd'), 'white', {renderer: 'canvas'});
#                 var option_c3041e0f569e4cc6b7e877fef6358fbd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u5b8c\u6210\u7387",
#             "data": [
#                 0.56
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6307\u6807\u5b8c\u6210\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c3041e0f569e4cc6b7e877fef6358fbd.setOption(option_c3041e0f569e4cc6b7e877fef6358fbd);
#         });
#     </script>

# %%
import json
from pyecharts import options as opts
from pyecharts.charts import Page, Scatter

f = open(r"C:\Users\XY\Desktop\更新\NotebookPro\pyecharts数据集\scatters.json")
data = json.load(f)
xs = data['xs']
gb  = data['gb']

scatter = (
        Scatter()
        .add_xaxis(xs)
        .add_yaxis('关系',gb)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="销售额与高质宝贝数"),
            xaxis_opts=opts.AxisOpts(type_="value",splitline_opts=opts.SplitLineOpts(is_show=True)),  # 设置grid线条
            yaxis_opts=opts.AxisOpts(type_="value",splitline_opts=opts.SplitLineOpts(is_show=True)),
        )
    )
scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="835f79bf0a724b538db53e5e3316fff0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_835f79bf0a724b538db53e5e3316fff0 = echarts.init(
#                     document.getElementById('835f79bf0a724b538db53e5e3316fff0'), 'white', {renderer: 'canvas'});
#                 var option_835f79bf0a724b538db53e5e3316fff0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5173\u7cfb",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     16980,
#                     4834
#                 ],
#                 [
#                     12624,
#                     4016
#                 ],
#                 [
#                     24788,
#                     5614
#                 ],
#                 [
#                     26331,
#                     3979
#                 ],
#                 [
#                     26520,
#                     6012
#                 ],
#                 [
#                     27266,
#                     5959
#                 ],
#                 [
#                     24823,
#                     6123
#                 ],
#                 [
#                     24139,
#                     5656
#                 ],
#                 [
#                     32568,
#                     6131
#                 ],
#                 [
#                     33420,
#                     6160
#                 ],
#                 [
#                     47859,
#                     6891
#                 ],
#                 [
#                     34659,
#                     6367
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5173\u7cfb"
#             ],
#             "selected": {
#                 "\u5173\u7cfb": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 16980,
#                 12624,
#                 24788,
#                 26331,
#                 26520,
#                 27266,
#                 24823,
#                 24139,
#                 32568,
#                 33420,
#                 47859,
#                 34659
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u9500\u552e\u989d\u4e0e\u9ad8\u8d28\u5b9d\u8d1d\u6570",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_835f79bf0a724b538db53e5e3316fff0.setOption(option_835f79bf0a724b538db53e5e3316fff0);
#         });
#     </script>

# %% [markdown]
# **参考：**
# 1. 官网
# 2. [sinlearn博客](https://www.cnblogs.com/sinlearn/p/12673141.html)

# %% [markdown]
# ### 1.2 [配置项](http://pyecharts.org/#/zh-cn/global_options)
#
# 学到了再慢慢添加

# %% [markdown]
# | 归属 | 类型 | 含义 | 官网地址 |
# | :----- | :------ | :----- | :------ |
# | set_global_opts | opts.TitleOpts | 标题配置项 | [参考](http://pyecharts.org/#/zh-cn/global_options?id=titleopts%ef%bc%9a%e6%a0%87%e9%a2%98%e9%85%8d%e7%bd%ae%e9%a1%b9) |
# |  | opts.DataZoomOpts | 区域缩放 | [参考](http://pyecharts.org/#/zh-cn/global_options?id=datazoomopts%ef%bc%9a%e5%8c%ba%e5%9f%9f%e7%bc%a9%e6%94%be%e9%85%8d%e7%bd%ae%e9%a1%b9) |
# |  | opts.VisualMapOpts | 视觉对象配置 |
# |  | opts.CalendarOpts | 日历 | Shift+tab |
#
# **备注**
# 归属：整个的大类
# 类型：子类
# 所以调用时候是: .归属( 类型1, 类型2[, ..] )

# %% [markdown]
# ## 专辑——地图专栏

# %% [markdown]
# ### 1. 基础

# %%
from pyecharts.charts import Map

# 用于测试的例子，部分取自 Faker ，也就是 from pyecharts.faker import Faker
provinces = ["广东", "北京", "上海", "辽宁", "湖南", "四川", "西藏"]
guangdong_city = ["汕头市", "汕尾市", "揭阳市", "阳江市", "肇庆市", "广州市", "惠州市"]
country = ["China", "Canada", "Brazil", "Russia", "United States", "Africa", "Germany"]
value = [300, 100, 2000, 800, 10000, 400, 5000]

map = (
        Map()
        .add("", [list(z) for z in zip(provinces, value)], "china")
        .set_global_opts(title_opts=opts.TitleOpts(title="map-基本图形"))
    )
map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="84a89da01f5542ffa71a79ff81bc29eb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_84a89da01f5542ffa71a79ff81bc29eb = echarts.init(
#                     document.getElementById('84a89da01f5542ffa71a79ff81bc29eb'), 'white', {renderer: 'canvas'});
#                 var option_84a89da01f5542ffa71a79ff81bc29eb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 300
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 2000
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 800
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 10000
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 400
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 5000
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "map-\u57fa\u672c\u56fe\u5f62",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_84a89da01f5542ffa71a79ff81bc29eb.setOption(option_84a89da01f5542ffa71a79ff81bc29eb);
#         });
#     </script>

# %%
map1 = (
        Map()
        .add("", [list(z) for z in zip(provinces, value)], "china")
        .set_global_opts(
            title_opts=opts.TitleOpts(title="连续型数据"),
            visualmap_opts=opts.VisualMapOpts(max_= 12000),
        )
)

map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="4af2b4b9be1f4b0ea5c795c747208e45" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_4af2b4b9be1f4b0ea5c795c747208e45 = echarts.init(
#                     document.getElementById('4af2b4b9be1f4b0ea5c795c747208e45'), 'white', {renderer: 'canvas'});
#                 var option_4af2b4b9be1f4b0ea5c795c747208e45 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 300
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 2000
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 800
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 10000
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 400
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 5000
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8fde\u7eed\u578b\u6570\u636e",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 12000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_4af2b4b9be1f4b0ea5c795c747208e45.setOption(option_4af2b4b9be1f4b0ea5c795c747208e45);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.guangdong_city, Faker.values())], "广东")
    
    
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="82a50c834f854157bdc3388bd2de31e4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_82a50c834f854157bdc3388bd2de31e4 = echarts.init(
#                     document.getElementById('82a50c834f854157bdc3388bd2de31e4'), 'white', {renderer: 'canvas'});
#                 var option_82a50c834f854157bdc3388bd2de31e4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u5e7f\u4e1c",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": 137
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": 145
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": 122
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": 123
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-\u5e7f\u4e1c\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_82a50c834f854157bdc3388bd2de31e4.setOption(option_82a50c834f854157bdc3388bd2de31e4);
#         });
#     </script>

# %%
prov_city = ['黄冈市', '咸宁市', '襄阳市', '武汉市']
data_prov_city = [(i, random.randint(100, 200)) for i in prov_city]
province_city = (
    Map()
    .add("", data_prov_city, "湖北")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="某省地级市地图"),
        visualmap_opts=opts.VisualMapOpts( min_=100, max_=200, is_piecewise=True )
    )
)

province_city.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '湖北':'https://assets.pyecharts.org/assets/maps/hubei'
#         }
#     });
# </script>
#
#         <div id="42a4438c42eb42c3a01b9b211f46d70e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '湖北'], function(echarts) {
#                 var chart_42a4438c42eb42c3a01b9b211f46d70e = echarts.init(
#                     document.getElementById('42a4438c42eb42c3a01b9b211f46d70e'), 'white', {renderer: 'canvas'});
#                 var option_42a4438c42eb42c3a01b9b211f46d70e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u6e56\u5317",
#             "data": [
#                 {
#                     "name": "\u9ec4\u5188\u5e02",
#                     "value": 140
#                 },
#                 {
#                     "name": "\u54b8\u5b81\u5e02",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u8944\u9633\u5e02",
#                     "value": 169
#                 },
#                 {
#                     "name": "\u6b66\u6c49\u5e02",
#                     "value": 183
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u67d0\u7701\u5730\u7ea7\u5e02\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 100,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_42a4438c42eb42c3a01b9b211f46d70e.setOption(option_42a4438c42eb42c3a01b9b211f46d70e);
#         });
#     </script>

# %%
counties = (
    Map()
    .add( "", [['罗田县', 1]], "黄冈"
#          , label_opts=opts.LabelOpts(is_show=False)  # 是否显示标签
        )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="中国某市县地图"),
        visualmap_opts=opts.VisualMapOpts(),
    )
)

counties.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '黄冈':'https://assets.pyecharts.org/assets/maps/hu2_bei3_huang2_gang1'
#         }
#     });
# </script>
#
#         <div id="526f76dc9b1345728716f3d2e68795e9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '黄冈'], function(echarts) {
#                 var chart_526f76dc9b1345728716f3d2e68795e9 = echarts.init(
#                     document.getElementById('526f76dc9b1345728716f3d2e68795e9'), 'white', {renderer: 'canvas'});
#                 var option_526f76dc9b1345728716f3d2e68795e9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u9ec4\u5188",
#             "data": [
#                 {
#                     "name": "\u7f57\u7530\u53bf",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e2d\u56fd\u67d0\u5e02\u53bf\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_526f76dc9b1345728716f3d2e68795e9.setOption(option_526f76dc9b1345728716f3d2e68795e9);
#         });
#     </script>

# %%
wuhan = (
    Map()
    .add( "",  [list(z) for z in zip(['青山区','东西湖区','洪山区','汉阳区','武昌区'], [150,100,300,200,500])], "武汉")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="中国某市县地图"),
        visualmap_opts=opts.VisualMapOpts(min_=100, max_=500)
    )
)

wuhan.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '武汉':'https://assets.pyecharts.org/assets/maps/hu2_bei3_wu3_han4'
#         }
#     });
# </script>
#
#         <div id="2e453e8016cf4110b926fba22a57517f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '武汉'], function(echarts) {
#                 var chart_2e453e8016cf4110b926fba22a57517f = echarts.init(
#                     document.getElementById('2e453e8016cf4110b926fba22a57517f'), 'white', {renderer: 'canvas'});
#                 var option_2e453e8016cf4110b926fba22a57517f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u6b66\u6c49",
#             "data": [
#                 {
#                     "name": "\u9752\u5c71\u533a",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u4e1c\u897f\u6e56\u533a",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u6d2a\u5c71\u533a",
#                     "value": 300
#                 },
#                 {
#                     "name": "\u6c49\u9633\u533a",
#                     "value": 200
#                 },
#                 {
#                     "name": "\u6b66\u660c\u533a",
#                     "value": 500
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e2d\u56fd\u67d0\u5e02\u53bf\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 100,
#         "max": 500,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_2e453e8016cf4110b926fba22a57517f.setOption(option_2e453e8016cf4110b926fba22a57517f);
#         });
#     </script>

# %%
from pyecharts.charts import Geo
from pyecharts.globals import ChartType

c = (
        Geo()
        .add_schema(maptype="武汉")  # 展示区域的选择
        .add(
            "geo",
            [list(z) for z in zip(['青山区','东西湖区','洪山区','汉阳区','武昌区'], [150,100,300,200,500])]
            , type_=ChartType.EFFECT_SCATTER,
        )
#         .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(),
            title_opts=opts.TitleOpts(title="Geo-HeatMap"),
        )
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '武汉':'https://assets.pyecharts.org/assets/maps/hu2_bei3_wu3_han4'
#         }
#     });
# </script>
#
#         <div id="94786f9885df4bf1aabdc81358c3abac" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '武汉'], function(echarts) {
#                 var chart_94786f9885df4bf1aabdc81358c3abac = echarts.init(
#                     document.getElementById('94786f9885df4bf1aabdc81358c3abac'), 'white', {renderer: 'canvas'});
#                 var option_94786f9885df4bf1aabdc81358c3abac = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u9752\u5c71\u533a",
#                     "value": [
#                         114.38,
#                         30.63,
#                         150
#                     ]
#                 },
#                 {
#                     "name": "\u4e1c\u897f\u6e56\u533a",
#                     "value": [
#                         114.13,
#                         30.62,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u6d2a\u5c71\u533a",
#                     "value": [
#                         114.33,
#                         30.5,
#                         300
#                     ]
#                 },
#                 {
#                     "name": "\u6c49\u9633\u533a",
#                     "value": [
#                         114.27,
#                         30.55,
#                         200
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u660c\u533a",
#                     "value": [
#                         114.3,
#                         30.57,
#                         500
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-HeatMap",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "\u6b66\u6c49",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_94786f9885df4bf1aabdc81358c3abac.setOption(option_94786f9885df4bf1aabdc81358c3abac);
#         });
#     </script>

# %% [markdown]
# 有的点移位了... -_-|||
